# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import LabelEncoder
import os.path
import torch.nn.functional as F
from torch.nn import init
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import random
from time import time
from sklearn.metrics import mean_squared_error

# %%
date_2016 = pd.date_range(start='2016-01-01',end='2016-12-31',freq='D')
date_2017 = pd.date_range(start='2017-01-01',end='2017-12-31',freq='D')
date_2016_df = pd.DataFrame({'quarter':date_2016.quarter,'ones':np.ones(len(date_2016)),'date':pd.Series(date_2016.date).apply(str)})
date_2017_df = pd.DataFrame({'quarter':date_2017.quarter,'ones':np.ones(len(date_2017)),'date':pd.Series(date_2017.date).apply(str)})

# %%
date_2016_df['dayofquarter'] = date_2016_df.groupby('quarter',as_index=False)['ones'].cumsum()
date_2017_df['dayofquarter'] = date_2017_df.groupby('quarter',as_index=False)['ones'].cumsum()

# %%
quarter_info = pd.concat([date_2016_df[['date','dayofquarter']],date_2017_df[['date','dayofquarter']]],axis=0)

# %%
train_data = pd.read_csv('./data/air_visit_nn.csv')
test_data = pd.read_csv('./data/sample_submission_nn.csv')

# %%
train_data.head()
# Out:
#            air_store_id  visit_date  visitors air_genre_name  \
# 0  air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1  air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2  air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3  air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4  air_ba937bf13d40fb24  2016-01-18         6     Dining bar
#
#                   air_area_name calendar_date day_of_week  holiday_flg  year  \
# 0  Tōkyō-to Minato-ku Shibakōen    2016-01-13   Wednesday            0  2016
# 1  Tōkyō-to Minato-ku Shibakōen    2016-01-14    Thursday            0  2016
# 2  Tōkyō-to Minato-ku Shibakōen    2016-01-15      Friday            0  2016
# 3  Tōkyō-to Minato-ku Shibakōen    2016-01-16    Saturday            0  2016
# 4  Tōkyō-to Minato-ku Shibakōen    2016-01-18      Monday            0  2016
#
#    month  day  dayofyear  quarter
# 0      1   13         13        1
# 1      1   14         14        1
# 2      1   15         15        1
# 3      1   16         16        1
# 4      1   18         18        1

# %%
train_data = pd.merge(right=train_data,left=quarter_info,how='right',right_on='visit_date',left_on='date')
test_data = pd.merge(right=test_data,left=quarter_info,how='right',right_on='visit_date',left_on='date')

# %%
test_data.head()
# Out:
#          date  dayofquarter                               id  visitors  \
# 0  2017-04-23          23.0  air_00a91d42b08b08d9_2017-04-23         0
# 1  2017-04-23          23.0  air_0164b9927d20bcc3_2017-04-23         0
# 2  2017-04-23          23.0  air_0241aa3964b7f861_2017-04-23         0
# 3  2017-04-23          23.0  air_0328696196e46f18_2017-04-23         0
# 4  2017-04-23          23.0  air_034a3d5b40d5b1b1_2017-04-23         0
#
#            air_store_id  visit_date  air_genre_name  \
# 0  air_00a91d42b08b08d9  2017-04-23  Italian/French
# 1  air_0164b9927d20bcc3  2017-04-23  Italian/French
# 2  air_0241aa3964b7f861  2017-04-23         Izakaya
# 3  air_0328696196e46f18  2017-04-23      Dining bar
# 4  air_034a3d5b40d5b1b1  2017-04-23     Cafe/Sweets
#
#                      air_area_name calendar_date day_of_week  holiday_flg  \
# 0  Tōkyō-to Chiyoda-ku Kudanminami    2017-04-23      Sunday            0
# 1     Tōkyō-to Minato-ku Shibakōen    2017-04-23      Sunday            0
# 2    Tōkyō-to Taitō-ku Higashiueno    2017-04-23      Sunday            0
# 3     Ōsaka-fu Ōsaka-shi Nakanochō    2017-04-23      Sunday            0
# 4       Ōsaka-fu Ōsaka-shi Ōhiraki    2017-04-23      Sunday            0
#
#    year  month  day  dayofyear  quarter
# 0  2017      4   23        113        2
# 1  2017      4   23        113        2
# 2  2017      4   23        113        2
# 3  2017      4   23        113        2
# 4  2017      4   23        113        2

# %%
train_data.head()
# Out:
#          date  dayofquarter          air_store_id  visit_date  visitors  \
# 0  2016-01-01           1.0  air_d0e8a085d8dc83aa  2016-01-01         8
# 1  2016-01-01           1.0  air_5c65468938c07fa5  2016-01-01         8
# 2  2016-01-01           1.0  air_f690c42545146e0a  2016-01-01         7
# 3  2016-01-01           1.0  air_09a845d5b5944b01  2016-01-01        56
# 4  2016-01-01           1.0  air_d0a7bd3339c3d12a  2016-01-01        62
#
#   air_genre_name                              air_area_name calendar_date  \
# 0    Cafe/Sweets  Hyōgo-ken Kōbe-shi Sumiyoshi Higashimachi    2016-01-01
# 1          Other                Tōkyō-to Shibuya-ku Shibuya    2016-01-01
# 2  Japanese food      Hokkaidō Sapporo-shi Minami 3 Jōnishi    2016-01-01
# 3        Izakaya          Fukuoka-ken Kurume-shi Jōnanmachi    2016-01-01
# 4    Cafe/Sweets              Tōkyō-to Taitō-ku Higashiueno    2016-01-01
#
#   day_of_week  holiday_flg  year  month  day  dayofyear  quarter
# 0      Friday            1  2016      1    1          1        1
# 1      Friday            1  2016      1    1          1        1
# 2      Friday            1  2016      1    1          1        1
# 3      Friday            1  2016      1    1          1        1
# 4      Friday            1  2016      1    1          1        1

# %% [markdown]
# ## get the dictionaries.

# %%
store_set = set(train_data.air_store_id)
genre_set = set(train_data.air_genre_name)
area_set = set(train_data.air_area_name)
weekday_set = set(train_data.day_of_week)
holiday_set = set(train_data.holiday_flg)
year_set = set(train_data.year)
month_set =set(train_data.month)
day_set = set(train_data.day)
dayofyear_set = set(train_data.dayofyear)
quarter_set = set(train_data.quarter)
dayofquarter_set = set(train_data.dayofquarter)

# %%
store_index_dict = {store:i for i,store in enumerate(store_set)}
genre_index_dict = {genre:i for i,genre in enumerate(genre_set)}
area_index_dict = {area:i for i,area in enumerate(area_set)}
weekday_index_dict = {weekday:i for i,weekday in enumerate(weekday_set)}
holiday_index_dict = {holi:i for i,holi in enumerate(holiday_set)}
year_index_dict = {year:i for i,year in enumerate(year_set)}
month_index_dict = {month:i for i,month in enumerate(month_set)}
day_index_dict = {day:i for i,day in enumerate(day_set)}
dayofyear_index_dict = {dayofyear:i for i,dayofyear in enumerate(dayofyear_set)}
quarter_index_dict = {quarter:i for i,quarter in enumerate(quarter_set)}
dayofquarter_index_dict = {dayofquarter:i for i,dayofquarter in enumerate(dayofquarter_set)}

# %%
def store_index(data):
    return store_index_dict[data]
def genre_index(data):
    return genre_index_dict[data]
def area_index(data):
    return area_index_dict[data]
def weekday_index(data):
    return weekday_index_dict[data]
def holiday_index(data):
    return holiday_index_dict[data]
def year_index(data):
    return year_index_dict[data]
def month_index(data):
    return month_index_dict[data]
def day_index(data):
    return day_index_dict[data]
def dayofyear_index(data):
    return dayofyear_index_dict[data]
def quarter_index(data):
    return quarter_index_dict[data]
def dayofquarter_index(data):
    return dayofquarter_index_dict[data]

# %% [markdown]
# ## set up data sets

# %%
test_data.head()
# Out:
#          date  dayofquarter                               id  visitors  \
# 0  2017-04-23          23.0  air_00a91d42b08b08d9_2017-04-23         0
# 1  2017-04-23          23.0  air_0164b9927d20bcc3_2017-04-23         0
# 2  2017-04-23          23.0  air_0241aa3964b7f861_2017-04-23         0
# 3  2017-04-23          23.0  air_0328696196e46f18_2017-04-23         0
# 4  2017-04-23          23.0  air_034a3d5b40d5b1b1_2017-04-23         0
#
#            air_store_id  visit_date  air_genre_name  \
# 0  air_00a91d42b08b08d9  2017-04-23  Italian/French
# 1  air_0164b9927d20bcc3  2017-04-23  Italian/French
# 2  air_0241aa3964b7f861  2017-04-23         Izakaya
# 3  air_0328696196e46f18  2017-04-23      Dining bar
# 4  air_034a3d5b40d5b1b1  2017-04-23     Cafe/Sweets
#
#                      air_area_name calendar_date day_of_week  holiday_flg  \
# 0  Tōkyō-to Chiyoda-ku Kudanminami    2017-04-23      Sunday            0
# 1     Tōkyō-to Minato-ku Shibakōen    2017-04-23      Sunday            0
# 2    Tōkyō-to Taitō-ku Higashiueno    2017-04-23      Sunday            0
# 3     Ōsaka-fu Ōsaka-shi Nakanochō    2017-04-23      Sunday            0
# 4       Ōsaka-fu Ōsaka-shi Ōhiraki    2017-04-23      Sunday            0
#
#    year  month  day  dayofyear  quarter
# 0  2017      4   23        113        2
# 1  2017      4   23        113        2
# 2  2017      4   23        113        2
# 3  2017      4   23        113        2
# 4  2017      4   23        113        2

# %%
len(set(test_data.visit_date))
# Out:
# 39

# %%
len(set(train_data.visit_date))
# Out:
# 478

# %%
len(list(set(train_data.visit_date))[-39:])
# Out:
# 39

# %% [markdown]
# ## skip following lines the mask takes too much time

# %%
def valid_mask(data):
    if data.visit_date in list(set(train_data.visit_date))[-39:]:
        return True
    else:
        return False
def train_mask(data):
    if data.visit_date in list(set(train_data.visit_date))[-39:]:
        return False
    else:
        return True

# %%
train_data.iloc[:3].apply(valid_mask,axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
data_valid = train_data[train_data.apply(valid_mask,axis=1)]

# %%
data_train = train_data[train_data.apply(train_mask,axis=1)]

# %%
data_valid.shape
# Out:
# (20535, 15)

# %%
with open('train_valid_doq.pickle','wb') as f:
    pickle.dump((data_train,data_valid),f)

# %% [markdown]
# ## start from here

# %%
with open('train_valid_doq.pickle','rb') as f:
    data_train,data_valid = pickle.load(f)

# %%
data_train.head()
# Out:
#          date  dayofquarter          air_store_id  visit_date  visitors  \
# 0  2016-01-01           1.0  air_d0e8a085d8dc83aa  2016-01-01         8
# 1  2016-01-01           1.0  air_5c65468938c07fa5  2016-01-01         8
# 2  2016-01-01           1.0  air_f690c42545146e0a  2016-01-01         7
# 3  2016-01-01           1.0  air_09a845d5b5944b01  2016-01-01        56
# 4  2016-01-01           1.0  air_d0a7bd3339c3d12a  2016-01-01        62
#
#   air_genre_name                              air_area_name calendar_date  \
# 0    Cafe/Sweets  Hyōgo-ken Kōbe-shi Sumiyoshi Higashimachi    2016-01-01
# 1          Other                Tōkyō-to Shibuya-ku Shibuya    2016-01-01
# 2  Japanese food      Hokkaidō Sapporo-shi Minami 3 Jōnishi    2016-01-01
# 3        Izakaya          Fukuoka-ken Kurume-shi Jōnanmachi    2016-01-01
# 4    Cafe/Sweets              Tōkyō-to Taitō-ku Higashiueno    2016-01-01
#
#   day_of_week  holiday_flg  year  month  day  dayofyear  quarter
# 0      Friday            1  2016      1    1          1        1
# 1      Friday            1  2016      1    1          1        1
# 2      Friday            1  2016      1    1          1        1
# 3      Friday            1  2016      1    1          1        1
# 4      Friday            1  2016      1    1          1        1

# %%
data_valid.head()
# Out:
#           date  dayofquarter          air_store_id  visit_date  visitors  \
# 48  2016-01-02           2.0  air_5c65468938c07fa5  2016-01-02         8
# 49  2016-01-02           2.0  air_9fc607777ad76b26  2016-01-02        16
# 50  2016-01-02           2.0  air_326ca454ef3558bc  2016-01-02         6
# 51  2016-01-02           2.0  air_f690c42545146e0a  2016-01-02         2
# 52  2016-01-02           2.0  air_54d6c25d33f5260e  2016-01-02        32
#
#    air_genre_name                          air_area_name calendar_date  \
# 48          Other            Tōkyō-to Shibuya-ku Shibuya    2016-01-02
# 49          Other          Tōkyō-to Meguro-ku Kamimeguro    2016-01-02
# 50        Izakaya     Shizuoka-ken Shizuoka-shi Ōtemachi    2016-01-02
# 51  Japanese food  Hokkaidō Sapporo-shi Minami 3 Jōnishi    2016-01-02
# 52        Izakaya       Fukuoka-ken Fukuoka-shi Shiobaru    2016-01-02
#
#    day_of_week  holiday_flg  year  month  day  dayofyear  quarter
# 48    Saturday            1  2016      1    2          2        1
# 49    Saturday            1  2016      1    2          2        1
# 50    Saturday            1  2016      1    2          2        1
# 51    Saturday            1  2016      1    2          2        1
# 52    Saturday            1  2016      1    2          2        1

# %%
# normalize y
'''
y_train = pd.concat([data_train.visitors,data_valid.visitors],axis=0).values
max_log_y = np.max(np.log(y_train))
def get_y(data):
    return np.log(data)/max_log_y
'''
y_train = data_train.visitors.apply(np.log1p)
y_valid = data_valid.visitors.apply(np.log1p)

# %% [markdown]
# ## set up data for train

# %%
xtrain_dict = {
    'store':data_train.air_store_id.apply(store_index).values,
    'genre':data_train.air_genre_name.apply(genre_index).values,
    'area':data_train.air_area_name.apply(area_index).values,
    'weekday':data_train.day_of_week.apply(weekday_index).values,
    'holiday':data_train.holiday_flg.apply(holiday_index).values,
    'year':data_train.year.apply(year_index).values,
    'month':data_train.month.apply(month_index).values,
    'day':data_train.day.apply(day_index).values,
    'dayofyear':data_train.dayofyear.apply(dayofyear_index).values,
    'quarter':data_train.quarter.apply(quarter_index).values,
    'dayofquarter':data_train.dayofquarter.apply(dayofquarter_index).values
}
xval_dict = {
    'store':data_valid.air_store_id.apply(store_index).values,
    'genre':data_valid.air_genre_name.apply(genre_index).values,
    'area':data_valid.air_area_name.apply(area_index).values,
    'weekday':data_valid.day_of_week.apply(weekday_index).values,
    'holiday':data_valid.holiday_flg.apply(holiday_index).values,
    'year':data_valid.year.apply(year_index).values,
    'month':data_valid.month.apply(month_index).values,
    'day':data_valid.day.apply(day_index).values,
    'dayofyear':data_valid.dayofyear.apply(dayofyear_index).values,
    'quarter':data_valid.quarter.apply(quarter_index).values,
    'dayofquarter':data_valid.dayofquarter.apply(dayofquarter_index).values
}
xval_dict_for_val = {
    'store':Variable(torch.LongTensor(data_valid.air_store_id.apply(store_index).values),requires_grad=False),
    'genre':Variable(torch.LongTensor(data_valid.air_genre_name.apply(genre_index).values),requires_grad=False),
    'area':Variable(torch.LongTensor(data_valid.air_area_name.apply(area_index).values),requires_grad=False),
    'weekday':Variable(torch.LongTensor(data_valid.day_of_week.apply(weekday_index).values),requires_grad=False),
    'holiday':Variable(torch.LongTensor(data_valid.holiday_flg.apply(holiday_index).values),requires_grad=False),
    'year':Variable(torch.LongTensor(data_valid.year.apply(year_index).values),requires_grad=False),
    'month':Variable(torch.LongTensor(data_valid.month.apply(month_index).values),requires_grad=False),
    'day':Variable(torch.LongTensor(data_valid.day.apply(day_index).values),requires_grad=False),
    'dayofyear':Variable(torch.LongTensor(data_valid.dayofyear.apply(dayofyear_index).values),requires_grad=False),
    'quarter':Variable(torch.LongTensor(data_valid.quarter.apply(quarter_index).values),requires_grad=False),
    'dayofquarter':Variable(torch.LongTensor(data_valid.dayofquarter.apply(dayofquarter_index).values),requires_grad=False)
}
xtest_dict = {
    'store':Variable(torch.LongTensor(test_data.air_store_id.apply(store_index).values),requires_grad=False),
    'genre':Variable(torch.LongTensor(test_data.air_genre_name.apply(genre_index).values),requires_grad=False),
    'area':Variable(torch.LongTensor(test_data.air_area_name.apply(area_index).values),requires_grad=False),
    'weekday':Variable(torch.LongTensor(test_data.day_of_week.apply(weekday_index).values),requires_grad=False),
    'holiday':Variable(torch.LongTensor(test_data.holiday_flg.apply(holiday_index).values),requires_grad=False),
    'year':Variable(torch.LongTensor(test_data.year.apply(year_index).values),requires_grad=False),
    'month':Variable(torch.LongTensor(test_data.month.apply(month_index).values),requires_grad=False),
    'day':Variable(torch.LongTensor(test_data.day.apply(day_index).values),requires_grad=False),
    'dayofyear':Variable(torch.LongTensor(test_data.dayofyear.apply(dayofyear_index).values),requires_grad=False),
    'quarter':Variable(torch.LongTensor(test_data.quarter.apply(quarter_index).values),requires_grad=False),
    'dayofquarter':Variable(torch.LongTensor(test_data.dayofquarter.apply(dayofquarter_index).values),requires_grad=False)
}

# %%
xval_df = pd.concat([pd.DataFrame(xval_dict),y_valid.reset_index(drop=True)],axis=1)
xtrain_df = pd.DataFrame(xtrain_dict)

# %%
xval_df.head()
# Out:
#    area  day  dayofquarter  dayofyear  genre  holiday  month  quarter  store  \
# 0    92    1             1          1      7        1      0        0    126
# 1    88    1             1          1      7        1      0        0     18
# 2    78    1             1          1      9        1      0        0     23
# 3    76    1             1          1      3        1      0        0    330
# 4    52    1             1          1      9        1      0        0    699
#
#    weekday  year  visitors
# 0        6     0  2.197225
# 1        6     0  2.833213
# 2        6     0  1.945910
# 3        6     0  1.098612
# 4        6     0  3.496508

# %%
def get_valid_data():
    data = xval_df.sample(100)
    y = data.visitors.values
    x = {
    'store':Variable(torch.LongTensor(data.store.values),requires_grad=False),
    'genre':Variable(torch.LongTensor(data.genre.values),requires_grad=False),
    'area':Variable(torch.LongTensor(data.area.values),requires_grad=False),
    'weekday':Variable(torch.LongTensor(data.weekday.values),requires_grad=False),
    'holiday':Variable(torch.LongTensor(data.holiday.values),requires_grad=False),
    'year':Variable(torch.LongTensor(data.year.values),requires_grad=False),
    'month':Variable(torch.LongTensor(data.month.values),requires_grad=False),
    'day':Variable(torch.LongTensor(data.day.values),requires_grad=False),
    'dayofyear':Variable(torch.LongTensor(data.dayofyear.values),requires_grad=False),
    'quarter':Variable(torch.LongTensor(data.quarter.values),requires_grad=False),
    'dayofquarter':Variable(torch.LongTensor(data.dayofquarter.values),requires_grad=False)
    }
    return x,y

# %%
def batch_up(batch_size,features,labels):
    assert len(features) == len(labels)
    output_batch = []
    
    sample_size = len(features)
    for start_i in range(0,sample_size,batch_size):
        end_i = start_i + batch_size
        batch_feature = features[start_i:end_i]
        batch_label = labels[start_i:end_i]
        output_batch.append((batch_feature,batch_label))
        
    return output_batch

batched_train_data = batch_up(128,xtrain_df,y_train.values)

# %%
len(batched_train_data)
# Out:
# 1810

# %%
def get_x_dict(data):
    diction = {
    'store':Variable(torch.LongTensor(data.store.values)),
    'genre':Variable(torch.LongTensor(data.genre.values)),
    'area':Variable(torch.LongTensor(data.area.values)),
    'weekday':Variable(torch.LongTensor(data.weekday.values)),
    'holiday':Variable(torch.LongTensor(data.holiday.values)),
    'year':Variable(torch.LongTensor(data.year.values)),
    'month':Variable(torch.LongTensor(data.month.values)),
    'day':Variable(torch.LongTensor(data.day.values)),
    'dayofyear':Variable(torch.LongTensor(data.dayofyear.values)),
    'quarter':Variable(torch.LongTensor(data.quarter.values)),
    'dayofquarter':Variable(torch.LongTensor(data.dayofquarter.values))
    }
    return diction

# %%
def retrive_y(data):
    return np.exp(data)-1
def rmsle(preds,real):
    return np.sqrt(mean_squared_error(real,preds))
def valid_full(model):
    ypreds = model(xval_dict_for_val).detach().numpy()
    #ypreds = pd.Series(ypreds.reshape((-1,))).apply(retrive_y).values
    #yreal = xval_df.visitors.values
    return rmsle(ypreds,y_valid.values)

# %%
def write_result(model,name='sub1.csv'):
    ypreds = model(xtest_dict).detach().numpy()
    ypreds = pd.Series(ypreds.reshape((-1,))).apply(retrive_y).values
    test_data['visitor'] = ypreds
    test_data[['id','visitor']].rename(columns={'visitor':'visitors'}).to_csv(name,index=False)

# %% [markdown]
# ## define network

# %%
print(len(store_set),len(genre_set),len(area_set),len(weekday_set),len(holiday_set),len(year_set),\
     len(month_set),len(day_set),len(dayofyear_set),len(quarter_set),len(dayofquarter_set))
# Out:
# 829 14 103 7 2 2 12 31 366 4 92

# %%
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor,self).__init__()
        
        self.store_embeddor = nn.Embedding(len(store_set),15)
        self.genre_embeddor = nn.Embedding(len(genre_set),6)
        self.area_embeddor = nn.Embedding(len(area_set),10)
        self.weekday_embeddor = nn.Embedding(len(weekday_set),3)
        self.holiday_embeddor = nn.Embedding(len(holiday_set),2)
        self.year_embeddor = nn.Embedding(len(year_set),2)
        self.month_embeddor = nn.Embedding(len(month_set),6)
        self.day_embeddor = nn.Embedding(len(day_set),8)
        self.dayofyear_embeddor = nn.Embedding(len(dayofyear_set),10)
        self.quarter_embeddor = nn.Embedding(len(quarter_set),2)
        self.dayofquarter_embeddor = nn.Embedding(len(dayofquarter_set),10)
        
        self.e2h = nn.Linear(74,2500)
        self.bn0 = nn.BatchNorm1d(2500)
        self.h2h1 = nn.Linear(2500,1800)
        self.bn1 = nn.BatchNorm1d(1800)
        self.h2h2 = nn.Linear(1800,1500)
        self.bn2 = nn.BatchNorm1d(1500)
        self.h2h3 = nn.Linear(1500,1200)
        self.bn3 = nn.BatchNorm1d(1200)
        self.h2h4 = nn.Linear(1200,880)
        self.bn4 = nn.BatchNorm1d(880)
        self.h2h5 = nn.Linear(880,580)
        self.bn5 = nn.BatchNorm1d(580)
        self.h2h6 = nn.Linear(580,300)
        self.bn6 = nn.BatchNorm1d(300)
        self.h2h7 = nn.Linear(300,100)
        self.bn7 = nn.BatchNorm1d(100)
        self.h2o = nn.Linear(100,1)
        
        self.dropout = nn.Dropout(0.1)
        
        for layer in [self.e2h,self.h2h1,self.h2h2,self.h2h3,self.h2h4,self.h2h5,self.h2h6,self.h2h7,self.h2o]:
            self.init_wb(layer)
            
    def init_wb(self,layer):
        init.normal(layer.weight,mean=0.,std=0.1)
        init.constant(layer.bias,0)
        
    def forward(self,inputs):
        store_embeds = self.store_embeddor(inputs['store']).view(-1,15)
        genre_embeds = self.genre_embeddor(inputs['genre']).view(-1,6)
        area_embeds = self.area_embeddor(inputs['area']).view(-1,10)
        weekday_embeds = self.weekday_embeddor(inputs['weekday']).view(-1,3)
        holiday_embeds = self.holiday_embeddor(inputs['holiday']).view(-1,2)
        year_embeds = self.year_embeddor(inputs['year']).view(-1,2)
        month_embeds = self.month_embeddor(inputs['month']).view(-1,6)
        day_embeds = self.day_embeddor(inputs['day']).view(-1,8)
        dayofyear_embeds = self.dayofyear_embeddor(inputs['dayofyear']).view(-1,10)
        quarter_embeds = self.quarter_embeddor(inputs['quarter']).view(-1,2)
        dayofquarter_embeds = self.dayofquarter_embeddor(inputs['dayofquarter']).view(-1,10)
        
        merged = torch.cat([store_embeds,genre_embeds,area_embeds,weekday_embeds,\
                        holiday_embeds,year_embeds,month_embeds,day_embeds,\
                        dayofyear_embeds,quarter_embeds,dayofquarter_embeds],1)
        goods = self.dropout(self.bn0(self.e2h(merged)).clamp(min=0))
        goods = self.dropout(self.bn1(self.h2h1(goods)).clamp(min=0))
        goods = self.dropout(self.bn2(self.h2h2(goods)).clamp(min=0))
        goods = self.dropout(self.bn3(self.h2h3(goods)).clamp(min=0))
        goods = self.dropout(self.bn4(self.h2h4(goods)).clamp(min=0))
        goods = self.dropout(self.bn5(self.h2h5(goods)).clamp(min=0))
        goods = self.dropout(self.bn6(self.h2h6(goods)).clamp(min=0))
        goods = self.dropout(self.bn7(self.h2h7(goods)).clamp(min=0))
        
        output = self.h2o(goods)
        return output

# %%
def train(epochs=5,lr=0.01,optimizer='Adamax'):
    print('\ntrain with optimizer {} and learning rate of {}'.format(optimizer,lr))
    train_mse_loss = []
    val_mse_loss = []
    val_rmsle_loss = []
    model = Regressor()
    loss_fn = nn.MSELoss()
    if optimizer == 'Adam':
        optimizer = optim.Adam(model.parameters(),lr=lr)
    elif optimizer == 'Adamax':
        optimizer = optim.Adamax(model.parameters(),lr=lr)
    elif optimizer == 'Adadelta':
        optimizer = optim.Adadelta(model.parameters(),lr=lr)
    elif optimizer == 'Adagrad':
        optimizer = optim.Adagrad(model.parameters(),lr=lr)
    elif optimizer == 'ASGD':
        optimizer = optim.ASGD(model.parameters(),lr=lr)
    elif optimizer == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(),lr=lr)
    elif optimizer == 'Rprop':
        optimizer = optim.Rprop(model.parameters(),lr=lr)
    elif optimizer == 'SGD':
        optimizer = optim.SGD(model.parameters(),lr=lr,momentum=0.8)
    data = batched_train_data
    for epoch in range(epochs):
        start = time()
        val_mse = []
        val_rmsle = []
        train_loss = []
        for i,(x,y) in enumerate(data):
            inputs = get_x_dict(x)
            outputs = Variable(torch.FloatTensor(y))
            preds = model(inputs)
            loss = loss_fn(preds,outputs)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            def validate_model(x,y):
                ypreds = model(x).detach().numpy()
                yreal = y
                return rmsle(ypreds,yreal)
            def mse_(x,y):
                ypreds = model(x).detach().numpy()
                return mean_squared_error(y,ypreds)
            x_,y_ = get_valid_data()
            val_mse.append(mse_(x_,y_))
            val_rmsle.append(validate_model(x_,y_))
            train_loss.append(loss.data[0])
            if i%100 == 0:
                train_mse_loss.append(np.mean(train_loss))
                val_mse_loss.append(np.mean(val_mse))
                val_rmsle_loss.append(np.mean(val_rmsle))
                train_loss = []
                val_mae = []
                val_rmsle = []
        print('epoch {} losses are {:.4f},{:.4f},and {:.4f} this epoch takes {:.2f} minutes'.format(\
                                                    epoch,train_mse_loss[-1],\
                                                   val_mse_loss[-1],\
                                                   val_rmsle_loss[-1],(time()-start)/60))
    return model,train_mse_loss,val_mse_loss,val_rmsle_loss

# %%
valid_full(model1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-50c3d89f675d> in <module>()
# ----> 1 valid_full(model1)
#
# NameError: name 'model1' is not defined

# %%
write_result(model1)

# %%
result = {op+'_'+str(lr):{} for op in ['Adamax','Adadelta','Adagrad','Adam','ASGD',\
                                       'RMSprop','Rprop','SGD'] for lr in [0.05,0.01,0.002,0.001]}

# %%
for op in ['Adamax','Adadelta','Adagrad','Adam','ASGD','RMSprop','Rprop','SGD']:
    for lr in [0.05,0.01,0.002,0.001]:
        _,train_mse_loss,val_mse_loss,val_rmsle_loss = train(epochs=10,lr=lr,optimizer=op)
        result[op+'_'+str(lr)]['train_loss'] = train_mse_loss
        result[op+'_'+str(lr)]['val_loss'] = val_mse_loss
        result[op+'_'+str(lr)]['val_mae_loss'] = val_rmsle_loss
# Out:
# train with optimizer Adamax and learning rate of 0.05
# epoch 0 losses are 0.3800,0.5932,and 0.7158 this epoch takes 8.27 minutes
# epoch 1 losses are 0.4106,0.4939,and 0.6844 this epoch takes 8.75 minutes
# epoch 2 losses are 0.4085,0.4514,and 0.6729 this epoch takes 9.37 minutes
# epoch 3 losses are 0.4043,0.4439,and 0.6710 this epoch takes 10.36 minutes
# epoch 4 losses are 0.4009,0.4407,and 0.6583 this epoch takes 11.45 minutes
# epoch 5 losses are 0.3992,0.4408,and 0.6637 this epoch takes 12.81 minutes
# epoch 6 losses are 0.3991,0.4427,and 0.6761 this epoch takes 13.75 minutes
# epoch 7 losses are 0.3931,0.4463,and 0.6730 this epoch takes 14.36 minutes
# epoch 8 losses are 0.3967,0.4491,and 0.6681 this epoch takes 14.71 minutes
# epoch 9 losses are 0.3894,0.4522,and 0.6716 this epoch takes 14.90 minutes
#
# train with optimizer Adamax and learning rate of 0.01
# epoch 0 losses are 0.4180,0.6210,and 0.7303 this epoch takes 7.87 minutes
# epoch 1 losses are 0.4126,0.5369,and 0.7269 this epoch takes 8.14 minutes
# epoch 2 losses are 0.4068,0.4960,and 0.7018 this epoch takes 8.27 minutes
# epoch 3 losses are 0.3918,0.4764,and 0.6842 this epoch takes 8.67 minutes
# epoch 4 losses are 0.3826,0.4698,and 0.6891 this epoch takes 9.00 minutes
# epoch 5 losses are 0.3725,0.4737,and 0.6952 this epoch takes 9.42 minutes
# epoch 6 losses are 0.3651,0.4804,and 0.6921 this epoch takes 9.30 minutes
# epoch 7 losses are 0.3598,0.4941,and 0.7044 this epoch takes 9.55 minutes
# epoch 8 losses are 0.3600,0.5108,and 0.7109 this epoch takes 9.47 minutes
# epoch 9 losses are 0.3502,0.5280,and 0.7300 this epoch takes 9.67 minutes
#
# train with optimizer Adamax and learning rate of 0.002
# epoch 0 losses are 0.4333,0.7087,and 0.7244 this epoch takes 7.88 minutes
# epoch 1 losses are 0.4062,0.5106,and 0.6977 this epoch takes 8.01 minutes
# epoch 2 losses are 0.3880,0.4837,and 0.6827 this epoch takes 8.16 minutes
# epoch 3 losses are 0.3783,0.4746,and 0.6877 this epoch takes 8.25 minutes
# epoch 4 losses are 0.3706,0.4758,and 0.6858 this epoch takes 8.09 minutes
# epoch 5 losses are 0.3606,0.4887,and 0.7046 this epoch takes 8.25 minutes
# epoch 6 losses are 0.3553,0.4942,and 0.7007 this epoch takes 8.23 minutes
# epoch 7 losses are 0.3528,0.4968,and 0.7122 this epoch takes 8.14 minutes
# epoch 8 losses are 0.3481,0.5156,and 0.7196 this epoch takes 8.37 minutes
# epoch 9 losses are 0.3437,0.5266,and 0.7277 this epoch takes 8.40 minutes
#
# train with optimizer Adamax and learning rate of 0.001
# epoch 0 losses are 0.4392,0.7808,and 0.7676 this epoch takes 7.72 minutes
# epoch 1 losses are 0.4067,0.5354,and 0.7147 this epoch takes 7.41 minutes
# epoch 2 losses are 0.3918,0.4995,and 0.6832 this epoch takes 8.10 minutes
# epoch 3 losses are 0.3760,0.4789,and 0.6876 this epoch takes 7.57 minutes
# epoch 4 losses are 0.3724,0.4728,and 0.6803 this epoch takes 7.94 minutes
# epoch 5 losses are 0.3676,0.4725,and 0.6939 this epoch takes 8.26 minutes
# epoch 6 losses are 0.3649,0.4783,and 0.6847 this epoch takes 8.19 minutes
# epoch 7 losses are 0.3561,0.4795,and 0.6896 this epoch takes 8.16 minutes
# epoch 8 losses are 0.3508,0.4861,and 0.7026 this epoch takes 8.04 minutes
# epoch 9 losses are 0.3448,0.4958,and 0.7070 this epoch takes 8.21 minutes
#
# train with optimizer Adadelta and learning rate of 0.05
# epoch 0 losses are 0.5460,1.4928,and 0.8513 this epoch takes 6.84 minutes
# epoch 1 losses are 0.4848,0.6936,and 0.8195 this epoch takes 6.50 minutes
# epoch 2 losses are 0.4585,0.6605,and 0.8016 this epoch takes 6.50 minutes
# epoch 3 losses are 0.4379,0.6341,and 0.7821 this epoch takes 7.46 minutes
# epoch 4 losses are 0.4238,0.6224,and 0.7917 this epoch takes 6.51 minutes
# epoch 5 losses are 0.4246,0.6093,and 0.7628 this epoch takes 6.55 minutes
# epoch 6 losses are 0.4146,0.5970,and 0.7606 this epoch takes 7.03 minutes
# epoch 7 losses are 0.4123,0.5902,and 0.7764 this epoch takes 6.82 minutes
# epoch 8 losses are 0.4067,0.5835,and 0.7580 this epoch takes 7.11 minutes
# epoch 9 losses are 0.3998,0.5774,and 0.7464 this epoch takes 6.66 minutes
#
# train with optimizer Adadelta and learning rate of 0.01
# epoch 0 losses are 0.7696,3.9687,and 0.9158 this epoch takes 7.46 minutes
# epoch 1 losses are 0.6813,0.8066,and 0.9006 this epoch takes 6.85 minutes
# epoch 2 losses are 0.6235,0.7768,and 0.8682 this epoch takes 6.90 minutes
# epoch 3 losses are 0.5930,0.7581,and 0.8635 this epoch takes 7.41 minutes
# epoch 4 losses are 0.5574,0.7366,and 0.8554 this epoch takes 7.52 minutes
# epoch 5 losses are 0.5380,0.7228,and 0.8412 this epoch takes 6.88 minutes
# epoch 6 losses are 0.5222,0.7119,and 0.8342 this epoch takes 7.39 minutes
# epoch 7 losses are 0.5084,0.7018,and 0.8289 this epoch takes 6.71 minutes
# epoch 8 losses are 0.4983,0.6924,and 0.8286 this epoch takes 6.60 minutes
# epoch 9 losses are 0.4872,0.6843,and 0.8198 this epoch takes 6.62 minutes
#
# train with optimizer Adadelta and learning rate of 0.002
# epoch 0 losses are 4.0696,6.0041,and 1.9974 this epoch takes 6.69 minutes
# epoch 1 losses are 1.4251,2.4225,and 1.1905 this epoch takes 6.70 minutes
# epoch 2 losses are 0.8713,1.0784,and 0.9608 this epoch takes 6.65 minutes
# epoch 3 losses are 0.7768,0.8682,and 0.9262 this epoch takes 6.50 minutes
# epoch 4 losses are 0.7492,0.8320,and 0.9063 this epoch takes 6.69 minutes
# epoch 5 losses are 0.7224,0.8178,and 0.8997 this epoch takes 6.54 minutes
# epoch 6 losses are 0.7268,0.8123,and 0.8983 this epoch takes 7.09 minutes
# epoch 7 losses are 0.7004,0.7959,and 0.8949 this epoch takes 7.29 minutes
# epoch 8 losses are 0.6842,0.7920,and 0.8957 this epoch takes 7.59 minutes
# epoch 9 losses are 0.6710,0.7864,and 0.8834 this epoch takes 6.82 minutes
#
# train with optimizer Adadelta and learning rate of 0.001
# epoch 0 losses are 7.5059,8.7370,and 2.7249 this epoch takes 7.30 minutes
# epoch 1 losses are 4.6247,5.8631,and 2.1235 this epoch takes 7.13 minutes
# epoch 2 losses are 2.5526,3.3827,and 1.5840 this epoch takes 6.59 minutes
# epoch 3 losses are 1.4840,1.8712,and 1.2157 this epoch takes 7.16 minutes
# epoch 4 losses are 1.0352,1.2130,and 1.0231 this epoch takes 7.57 minutes
# epoch 5 losses are 0.8555,0.9620,and 0.9482 this epoch takes 7.09 minutes
# epoch 6 losses are 0.7915,0.8621,and 0.9164 this epoch takes 6.53 minutes
# epoch 7 losses are 0.7610,0.8328,and 0.9150 this epoch takes 7.15 minutes
# epoch 8 losses are 0.7456,0.8157,and 0.9044 this epoch takes 6.74 minutes
# epoch 9 losses are 0.7421,0.8104,and 0.8941 this epoch takes 6.83 minutes
#
# train with optimizer Adagrad and learning rate of 0.05
# epoch 0 losses are 0.3598,0.5636,and 0.7032 this epoch takes 5.64 minutes
# epoch 1 losses are 0.3469,0.4788,and 0.6818 this epoch takes 5.93 minutes
# epoch 2 losses are 0.3438,0.4724,and 0.6926 this epoch takes 5.85 minutes
# epoch 3 losses are 0.3394,0.4764,and 0.6984 this epoch takes 5.67 minutes
# epoch 4 losses are 0.3363,0.4871,and 0.7070 this epoch takes 5.85 minutes
# epoch 5 losses are 0.3313,0.5023,and 0.7070 this epoch takes 5.98 minutes
# epoch 6 losses are 0.3265,0.5066,and 0.7153 this epoch takes 6.03 minutes
# epoch 7 losses are 0.3257,0.5188,and 0.7224 this epoch takes 6.02 minutes
# epoch 8 losses are 0.3211,0.5334,and 0.7357 this epoch takes 5.85 minutes
# epoch 9 losses are 0.3157,0.5471,and 0.7473 this epoch takes 5.95 minutes
#
# train with optimizer Adagrad and learning rate of 0.01
# epoch 0 losses are 0.4065,0.6035,and 0.7075 this epoch takes 6.06 minutes
# epoch 1 losses are 0.3860,0.5052,and 0.7090 this epoch takes 6.07 minutes
# epoch 2 losses are 0.3773,0.4891,and 0.6987 this epoch takes 6.07 minutes
# epoch 3 losses are 0.3744,0.4866,and 0.6977 this epoch takes 6.07 minutes
# epoch 4 losses are 0.3694,0.4819,and 0.7011 this epoch takes 6.06 minutes
# epoch 5 losses are 0.3643,0.4791,and 0.7001 this epoch takes 5.85 minutes
# epoch 6 losses are 0.3637,0.4783,and 0.6890 this epoch takes 5.87 minutes
# epoch 7 losses are 0.3612,0.4776,and 0.6810 this epoch takes 5.93 minutes
# epoch 8 losses are 0.3578,0.4776,and 0.6880 this epoch takes 6.04 minutes
# epoch 9 losses are 0.3553,0.4811,and 0.6934 this epoch takes 6.04 minutes
#
# train with optimizer Adagrad and learning rate of 0.002
# epoch 0 losses are 0.5459,1.1880,and 0.8325 this epoch takes 5.71 minutes
# epoch 1 losses are 0.5044,0.6957,and 0.8341 this epoch takes 6.07 minutes
# epoch 2 losses are 0.4874,0.6649,and 0.8038 this epoch takes 5.14 minutes
# epoch 3 losses are 0.4719,0.6492,and 0.8018 this epoch takes 4.87 minutes
# epoch 4 losses are 0.4676,0.6400,and 0.7815 this epoch takes 4.87 minutes
# epoch 5 losses are 0.4629,0.6251,and 0.7843 this epoch takes 4.86 minutes
# epoch 6 losses are 0.4566,0.6183,and 0.7849 this epoch takes 5.22 minutes
# epoch 7 losses are 0.4468,0.6143,and 0.7754 this epoch takes 6.08 minutes
# epoch 8 losses are 0.4473,0.6060,and 0.7789 this epoch takes 5.95 minutes
# epoch 9 losses are 0.4385,0.6041,and 0.7748 this epoch takes 6.09 minutes
#
# train with optimizer Adagrad and learning rate of 0.001
# epoch 0 losses are 0.7667,1.8395,and 0.9436 this epoch takes 6.09 minutes
# epoch 1 losses are 0.5824,0.7718,and 0.8459 this epoch takes 6.11 minutes
# epoch 2 losses are 0.5474,0.7193,and 0.8525 this epoch takes 6.10 minutes
# epoch 3 losses are 0.5336,0.7048,and 0.8323 this epoch takes 6.08 minutes
# epoch 4 losses are 0.5191,0.7005,and 0.8364 this epoch takes 6.03 minutes
# epoch 5 losses are 0.5051,0.6850,and 0.8260 this epoch takes 5.87 minutes
# epoch 6 losses are 0.5042,0.6799,and 0.8297 this epoch takes 5.02 minutes
# epoch 7 losses are 0.5004,0.6745,and 0.8104 this epoch takes 4.86 minutes
# epoch 8 losses are 0.4912,0.6716,and 0.8120 this epoch takes 4.86 minutes
# epoch 9 losses are 0.4939,0.6676,and 0.8122 this epoch takes 4.86 minutes
#
# train with optimizer Adam and learning rate of 0.05
# epoch 0 losses are 0.3867,0.5736,and 0.7040 this epoch takes 7.47 minutes
# epoch 1 losses are 0.3975,0.4990,and 0.7237 this epoch takes 9.12 minutes
# epoch 2 losses are 0.3910,0.5058,and 0.7244 this epoch takes 9.89 minutes
# epoch 3 losses are 0.3875,0.4965,and 0.7060 this epoch takes 10.40 minutes
# epoch 4 losses are 0.3857,0.4994,and 0.7060 this epoch takes 10.89 minutes
# epoch 5 losses are 0.3827,0.5018,and 0.7078 this epoch takes 11.37 minutes
# epoch 6 losses are 0.3771,0.5088,and 0.7005 this epoch takes 12.10 minutes
# epoch 7 losses are 0.3739,0.5088,and 0.7227 this epoch takes 12.79 minutes
# epoch 8 losses are 0.3777,0.5261,and 0.7476 this epoch takes 13.34 minutes
# epoch 9 losses are 0.3595,0.5318,and 0.7258 this epoch takes 13.78 minutes
#
# train with optimizer Adam and learning rate of 0.01
# epoch 0 losses are 0.3986,0.6191,and 0.7257 this epoch takes 6.36 minutes
# epoch 1 losses are 0.3949,0.4896,and 0.6894 this epoch takes 6.79 minutes
# epoch 2 losses are 0.4031,0.4622,and 0.6800 this epoch takes 7.72 minutes
# epoch 3 losses are 0.3970,0.4594,and 0.6735 this epoch takes 8.21 minutes
# epoch 4 losses are 0.3928,0.4517,and 0.6908 this epoch takes 8.63 minutes
# epoch 5 losses are 0.3859,0.4656,and 0.6894 this epoch takes 9.03 minutes
# epoch 6 losses are 0.3858,0.4674,and 0.6939 this epoch takes 9.31 minutes
# epoch 7 losses are 0.3798,0.4749,and 0.6951 this epoch takes 9.64 minutes
# epoch 8 losses are 0.3721,0.4860,and 0.7041 this epoch takes 10.12 minutes
# epoch 9 losses are 0.3763,0.5025,and 0.7079 this epoch takes 10.36 minutes
#
# train with optimizer Adam and learning rate of 0.002
# epoch 0 losses are 0.4281,0.6272,and 0.7296 this epoch takes 6.91 minutes
# epoch 1 losses are 0.4114,0.5097,and 0.7119 this epoch takes 6.75 minutes
# epoch 2 losses are 0.3956,0.5110,and 0.7204 this epoch takes 6.87 minutes
# epoch 3 losses are 0.3841,0.5166,and 0.7195 this epoch takes 6.63 minutes
# epoch 4 losses are 0.3698,0.5253,and 0.7203 this epoch takes 7.13 minutes
# epoch 5 losses are 0.3628,0.5345,and 0.7469 this epoch takes 7.51 minutes
# epoch 6 losses are 0.3541,0.5544,and 0.7393 this epoch takes 7.49 minutes
# epoch 7 losses are 0.3452,0.5723,and 0.7584 this epoch takes 7.74 minutes
# epoch 8 losses are 0.3376,0.5994,and 0.7820 this epoch takes 8.07 minutes
# epoch 9 losses are 0.3278,0.6176,and 0.7768 this epoch takes 8.11 minutes
#
# train with optimizer Adam and learning rate of 0.001
# epoch 0 losses are 0.4271,0.7498,and 0.7111 this epoch takes 6.81 minutes
# epoch 1 losses are 0.4020,0.5077,and 0.7072 this epoch takes 6.77 minutes
# epoch 2 losses are 0.3903,0.4970,and 0.6933 this epoch takes 6.87 minutes
# epoch 3 losses are 0.3777,0.4953,and 0.6926 this epoch takes 6.99 minutes
# epoch 4 losses are 0.3674,0.4971,and 0.7091 this epoch takes 6.79 minutes
# epoch 5 losses are 0.3587,0.5116,and 0.7234 this epoch takes 6.71 minutes
# epoch 6 losses are 0.3523,0.5290,and 0.7105 this epoch takes 7.04 minutes
# epoch 7 losses are 0.3439,0.5568,and 0.7514 this epoch takes 6.50 minutes
# epoch 8 losses are 0.3379,0.5860,and 0.7719 this epoch takes 7.01 minutes
# epoch 9 losses are 0.3332,0.6007,and 0.7739 this epoch takes 7.09 minutes
#
# train with optimizer ASGD and learning rate of 0.05
# epoch 0 losses are 0.4469,0.6987,and 0.7993 this epoch takes 5.56 minutes
# epoch 1 losses are 0.4008,0.6315,and 0.7873 this epoch takes 5.54 minutes
# epoch 2 losses are 0.3873,0.6080,and 0.7737 this epoch takes 5.36 minutes
# epoch 3 losses are 0.3814,0.5934,and 0.7758 this epoch takes 5.32 minutes
# epoch 4 losses are 0.3715,0.5795,and 0.7568 this epoch takes 5.57 minutes
# epoch 5 losses are 0.3678,0.5744,and 0.7529 this epoch takes 5.39 minutes
# epoch 6 losses are 0.3663,0.5691,and 0.7556 this epoch takes 5.31 minutes
# epoch 7 losses are 0.3620,0.5593,and 0.7492 this epoch takes 5.50 minutes
# epoch 8 losses are 0.3601,0.5551,and 0.7403 this epoch takes 5.36 minutes
# epoch 9 losses are 0.3605,0.5514,and 0.7442 this epoch takes 5.53 minutes
#
# train with optimizer ASGD and learning rate of 0.01
# epoch 0 losses are 0.6124,0.7633,and 0.8307 this epoch takes 5.50 minutes
# epoch 1 losses are 0.5379,0.6897,and 0.8333 this epoch takes 5.53 minutes
# epoch 2 losses are 0.4984,0.6765,and 0.8069 this epoch takes 5.45 minutes
# epoch 3 losses are 0.4684,0.6637,and 0.8155 this epoch takes 5.33 minutes
# epoch 4 losses are 0.4535,0.6528,and 0.8030 this epoch takes 5.32 minutes
# epoch 5 losses are 0.4422,0.6417,and 0.7939 this epoch takes 5.18 minutes
# epoch 6 losses are 0.4281,0.6372,and 0.7927 this epoch takes 5.50 minutes
# epoch 7 losses are 0.4200,0.6250,and 0.7839 this epoch takes 5.44 minutes
# epoch 8 losses are 0.4132,0.6236,and 0.7861 this epoch takes 5.37 minutes
# epoch 9 losses are 0.4111,0.6158,and 0.7759 this epoch takes 5.64 minutes
#
# train with optimizer ASGD and learning rate of 0.002
# epoch 0 losses are 0.7442,0.8991,and 0.8674 this epoch takes 4.72 minutes
# epoch 1 losses are 0.6920,0.7346,and 0.8511 this epoch takes 5.46 minutes
# epoch 2 losses are 0.6693,0.7140,and 0.8461 this epoch takes 5.55 minutes
# epoch 3 losses are 0.6418,0.7015,and 0.8304 this epoch takes 5.60 minutes
# epoch 4 losses are 0.6250,0.6984,and 0.8405 this epoch takes 10.71 minutes
# epoch 5 losses are 0.6088,0.6947,and 0.8298 this epoch takes 11.61 minutes
# epoch 6 losses are 0.5892,0.6898,and 0.8241 this epoch takes 11.71 minutes
# epoch 7 losses are 0.5745,0.6864,and 0.8228 this epoch takes 8.64 minutes
# epoch 8 losses are 0.5555,0.6876,and 0.8159 this epoch takes 11.56 minutes
# epoch 9 losses are 0.5438,0.6786,and 0.8187 this epoch takes 11.55 minutes
#
# train with optimizer ASGD and learning rate of 0.001
# epoch 0 losses are 0.7768,1.0386,and 0.8693 this epoch takes 11.48 minutes
# epoch 1 losses are 0.7214,0.7606,and 0.8580 this epoch takes 7.61 minutes
# epoch 2 losses are 0.7071,0.7350,and 0.8559 this epoch takes 11.09 minutes
# epoch 3 losses are 0.6895,0.7189,and 0.8409 this epoch takes 11.43 minutes
# epoch 4 losses are 0.6736,0.7163,and 0.8513 this epoch takes 11.56 minutes
# epoch 5 losses are 0.6541,0.7038,and 0.8402 this epoch takes 11.54 minutes
# epoch 6 losses are 0.6546,0.6990,and 0.8189 this epoch takes 11.63 minutes
# epoch 7 losses are 0.6444,0.6945,and 0.8280 this epoch takes 11.52 minutes
# epoch 8 losses are 0.6281,0.6910,and 0.8276 this epoch takes 11.54 minutes
# epoch 9 losses are 0.6234,0.6894,and 0.8253 this epoch takes 11.55 minutes
#
# train with optimizer RMSprop and learning rate of 0.05
# epoch 0 losses are 0.3745,0.7520,and 0.6868 this epoch takes 12.79 minutes
# epoch 1 losses are 0.3650,0.4628,and 0.6731 this epoch takes 12.75 minutes
# epoch 2 losses are 0.3595,0.4530,and 0.6822 this epoch takes 12.74 minutes
# epoch 3 losses are 0.3523,0.4573,and 0.6819 this epoch takes 13.16 minutes
# epoch 4 losses are 0.3478,0.4567,and 0.6794 this epoch takes 15.54 minutes
# epoch 5 losses are 0.3434,0.4651,and 0.6865 this epoch takes 15.93 minutes
# epoch 6 losses are 0.3409,0.4716,and 0.6871 this epoch takes 15.97 minutes
# epoch 7 losses are 0.3371,0.4761,and 0.7065 this epoch takes 16.00 minutes
# epoch 8 losses are 0.3399,0.4768,and 0.6922 this epoch takes 16.07 minutes
# epoch 9 losses are 0.3382,0.4844,and 0.7111 this epoch takes 16.13 minutes
#
# train with optimizer RMSprop and learning rate of 0.01
# epoch 0 losses are 0.3472,0.5778,and 0.6941 this epoch takes 12.55 minutes
# epoch 1 losses are 0.3348,0.4588,and 0.6753 this epoch takes 12.56 minutes
# epoch 2 losses are 0.3325,0.4464,and 0.6605 this epoch takes 12.57 minutes
# epoch 3 losses are 0.3266,0.4417,and 0.6698 this epoch takes 12.96 minutes
# epoch 4 losses are 0.3203,0.4433,and 0.6696 this epoch takes 14.37 minutes
# epoch 5 losses are 0.3164,0.4487,and 0.6707 this epoch takes 14.68 minutes
# epoch 6 losses are 0.3125,0.4558,and 0.6736 this epoch takes 14.98 minutes
# epoch 7 losses are 0.3105,0.4663,and 0.6758 this epoch takes 15.03 minutes
# epoch 8 losses are 0.3078,0.4722,and 0.6722 this epoch takes 15.16 minutes
# epoch 9 losses are 0.3069,0.4803,and 0.6946 this epoch takes 15.21 minutes
#
# train with optimizer RMSprop and learning rate of 0.002
# epoch 0 losses are 0.3632,0.5926,and 0.7155 this epoch takes 12.49 minutes
# epoch 1 losses are 0.3439,0.5165,and 0.7100 this epoch takes 12.40 minutes
# epoch 2 losses are 0.3346,0.5087,and 0.7188 this epoch takes 12.42 minutes
# epoch 3 losses are 0.3285,0.5280,and 0.7393 this epoch takes 12.56 minutes
# epoch 4 losses are 0.3221,0.5417,and 0.7505 this epoch takes 12.87 minutes
# epoch 5 losses are 0.3188,0.5706,and 0.7636 this epoch takes 13.11 minutes
# epoch 6 losses are 0.3148,0.6030,and 0.7920 this epoch takes 13.14 minutes
# epoch 7 losses are 0.3080,0.6348,and 0.8098 this epoch takes 13.19 minutes
# epoch 8 losses are 0.3041,0.6762,and 0.8189 this epoch takes 7.59 minutes
# epoch 9 losses are 0.3000,0.7091,and 0.8519 this epoch takes 6.78 minutes
#
# train with optimizer RMSprop and learning rate of 0.001
# epoch 0 losses are 0.3721,0.6042,and 0.7176 this epoch takes 6.27 minutes
# epoch 1 losses are 0.3517,0.5060,and 0.7086 this epoch takes 6.27 minutes
# epoch 2 losses are 0.3405,0.4959,and 0.7159 this epoch takes 6.28 minutes
# epoch 3 losses are 0.3319,0.4998,and 0.7166 this epoch takes 6.31 minutes
# epoch 4 losses are 0.3250,0.5128,and 0.7343 this epoch takes 6.41 minutes
# epoch 5 losses are 0.3206,0.5290,and 0.7284 this epoch takes 6.46 minutes
# epoch 6 losses are 0.3146,0.5410,and 0.7489 this epoch takes 6.49 minutes
# epoch 7 losses are 0.3091,0.5788,and 0.7672 this epoch takes 6.50 minutes
# epoch 8 losses are 0.3034,0.5936,and 0.7735 this epoch takes 6.52 minutes
# epoch 9 losses are 0.2988,0.6234,and 0.8077 this epoch takes 6.52 minutes
#
# train with optimizer Rprop and learning rate of 0.05
# epoch 0 losses are 0.4462,0.6129,and 0.7377 this epoch takes 12.47 minutes
# epoch 1 losses are 0.4278,0.5320,and 0.7314 this epoch takes 12.50 minutes
# epoch 2 losses are 0.4253,0.5210,and 0.7207 this epoch takes 12.59 minutes
# epoch 3 losses are 0.4219,0.5254,and 0.7232 this epoch takes 12.52 minutes
# epoch 4 losses are 0.4333,0.5248,and 0.7307 this epoch takes 12.45 minutes
# epoch 5 losses are 0.4297,0.5177,and 0.7118 this epoch takes 12.56 minutes
# epoch 6 losses are 0.4218,0.5178,and 0.7210 this epoch takes 12.49 minutes
# epoch 7 losses are 0.4206,0.5216,and 0.7266 this epoch takes 12.72 minutes
# epoch 8 losses are 0.4253,0.5159,and 0.7114 this epoch takes 12.54 minutes
# epoch 9 losses are 0.4278,0.5189,and 0.7128 this epoch takes 12.52 minutes
#
# train with optimizer Rprop and learning rate of 0.01
# epoch 0 losses are 0.4964,0.6106,and 0.7351 this epoch takes 12.91 minutes
# epoch 1 losses are 0.4722,0.5190,and 0.7178 this epoch takes 12.95 minutes
# epoch 2 losses are 0.4571,0.5119,and 0.7162 this epoch takes 12.90 minutes
# epoch 3 losses are 0.4490,0.5014,and 0.7093 this epoch takes 12.99 minutes
# epoch 4 losses are 0.4435,0.5021,and 0.7154 this epoch takes 12.94 minutes
# epoch 5 losses are 0.4385,0.4999,and 0.7027 this epoch takes 13.10 minutes
# epoch 6 losses are 0.4383,0.4972,and 0.6920 this epoch takes 13.02 minutes
# epoch 7 losses are 0.4382,0.4972,and 0.7030 this epoch takes 13.05 minutes
# epoch 8 losses are 0.4366,0.4915,and 0.7007 this epoch takes 12.99 minutes
# epoch 9 losses are 0.4306,0.4907,and 0.6899 this epoch takes 13.03 minutes
#
# train with optimizer Rprop and learning rate of 0.002
# epoch 0 losses are 0.7270,0.8424,and 0.8750 this epoch takes 13.04 minutes
# epoch 1 losses are 0.6743,0.7674,and 0.8639 this epoch takes 13.10 minutes
# epoch 2 losses are 0.6353,0.7418,and 0.8483 this epoch takes 13.13 minutes
# epoch 3 losses are 0.6132,0.7245,and 0.8368 this epoch takes 12.93 minutes
# epoch 4 losses are 0.5886,0.7038,and 0.8374 this epoch takes 13.05 minutes
# epoch 5 losses are 0.5622,0.6878,and 0.8234 this epoch takes 12.98 minutes
# epoch 6 losses are 0.5584,0.6830,and 0.8104 this epoch takes 13.02 minutes
# epoch 7 losses are 0.5396,0.6741,and 0.8070 this epoch takes 13.03 minutes
# epoch 8 losses are 0.5259,0.6638,and 0.8104 this epoch takes 13.06 minutes
# epoch 9 losses are 0.5202,0.6578,and 0.8042 this epoch takes 13.15 minutes
#
# train with optimizer Rprop and learning rate of 0.001
# epoch 0 losses are 0.7989,0.8829,and 0.9016 this epoch takes 13.01 minutes
# epoch 1 losses are 0.7369,0.8080,and 0.8885 this epoch takes 12.99 minutes
# epoch 2 losses are 0.7175,0.7807,and 0.8743 this epoch takes 13.15 minutes
# epoch 3 losses are 0.6932,0.7637,and 0.8723 this epoch takes 13.11 minutes
# epoch 4 losses are 0.6697,0.7533,and 0.8448 this epoch takes 13.11 minutes
# epoch 5 losses are 0.6470,0.7319,and 0.8574 this epoch takes 13.14 minutes
# epoch 6 losses are 0.6287,0.7224,and 0.8387 this epoch takes 12.97 minutes
# epoch 7 losses are 0.6106,0.7120,and 0.8389 this epoch takes 13.05 minutes
# epoch 8 losses are 0.5935,0.7033,and 0.8338 this epoch takes 13.10 minutes
# epoch 9 losses are 0.5811,0.6996,and 0.8264 this epoch takes 17.43 minutes
#
# train with optimizer SGD and learning rate of 0.05
# epoch 0 losses are 0.3902,0.6634,and 0.7654 this epoch takes 11.47 minutes
# epoch 1 losses are 0.3711,0.5703,and 0.7459 this epoch takes 11.56 minutes
# epoch 2 losses are 0.3638,0.5475,and 0.7265 this epoch takes 11.47 minutes
# epoch 3 losses are 0.3580,0.5339,and 0.7283 this epoch takes 11.47 minutes
# epoch 4 losses are 0.3565,0.5241,and 0.7224 this epoch takes 11.51 minutes
# epoch 5 losses are 0.3496,0.5251,and 0.7093 this epoch takes 11.52 minutes
# epoch 6 losses are 0.3482,0.5207,and 0.7215 this epoch takes 11.50 minutes
# epoch 7 losses are 0.3451,0.5177,and 0.7101 this epoch takes 11.49 minutes
# epoch 8 losses are 0.3471,0.5139,and 0.7115 this epoch takes 5.54 minutes
# epoch 9 losses are 0.3450,0.5195,and 0.7118 this epoch takes 5.59 minutes
#
# train with optimizer SGD and learning rate of 0.01
# epoch 0 losses are 0.4591,0.7224,and 0.8209 this epoch takes 5.40 minutes
# epoch 1 losses are 0.4217,0.6570,and 0.8006 this epoch takes 5.21 minutes
# epoch 2 losses are 0.4086,0.6336,and 0.7935 this epoch takes 5.39 minutes
# epoch 3 losses are 0.4050,0.6219,and 0.7772 this epoch takes 5.47 minutes
# epoch 4 losses are 0.4031,0.6083,and 0.7866 this epoch takes 5.34 minutes
# epoch 5 losses are 0.3987,0.6028,and 0.7695 this epoch takes 5.61 minutes
# epoch 6 losses are 0.3931,0.5985,and 0.7862 this epoch takes 5.40 minutes
# epoch 7 losses are 0.3911,0.5957,and 0.7714 this epoch takes 5.38 minutes
# epoch 8 losses are 0.3897,0.5880,and 0.7727 this epoch takes 5.40 minutes
# epoch 9 losses are 0.3888,0.5868,and 0.7645 this epoch takes 5.31 minutes
#
# train with optimizer SGD and learning rate of 0.002
# epoch 0 losses are 0.6378,0.7634,and 0.8255 this epoch takes 5.55 minutes
# epoch 1 losses are 0.5622,0.6835,and 0.8284 this epoch takes 4.57 minutes
# epoch 2 losses are 0.5133,0.6687,and 0.8075 this epoch takes 5.26 minutes
# epoch 3 losses are 0.4875,0.6536,and 0.8106 this epoch takes 5.54 minutes
# epoch 4 losses are 0.4672,0.6490,and 0.7918 this epoch takes 9.34 minutes
# epoch 5 losses are 0.4562,0.6370,and 0.7935 this epoch takes 11.04 minutes
# epoch 6 losses are 0.4463,0.6301,and 0.7957 this epoch takes 10.26 minutes
# epoch 7 losses are 0.4415,0.6240,and 0.7832 this epoch takes 11.55 minutes
# epoch 8 losses are 0.4361,0.6188,and 0.7790 this epoch takes 11.54 minutes
# epoch 9 losses are 0.4318,0.6074,and 0.7747 this epoch takes 11.44 minutes
#
# train with optimizer SGD and learning rate of 0.001
# epoch 0 losses are 0.6876,0.8228,and 0.8494 this epoch takes 11.34 minutes
# epoch 1 losses are 0.6357,0.7076,and 0.8381 this epoch takes 8.51 minutes
# epoch 2 losses are 0.5901,0.6983,and 0.8204 this epoch takes 5.52 minutes
# epoch 3 losses are 0.5625,0.6873,and 0.8236 this epoch takes 6.81 minutes
# epoch 4 losses are 0.5352,0.6872,and 0.8296 this epoch takes 11.61 minutes
# epoch 5 losses are 0.5156,0.6778,and 0.8133 this epoch takes 11.60 minutes
# epoch 6 losses are 0.4998,0.6739,and 0.8182 this epoch takes 11.59 minutes
# epoch 7 losses are 0.4914,0.6698,and 0.8188 this epoch takes 11.55 minutes
# epoch 8 losses are 0.4759,0.6708,and 0.8006 this epoch takes 11.61 minutes
# epoch 9 losses are 0.4719,0.6567,and 0.8074 this epoch takes 11.66 minutes

# %%
xtest_dict.keys()
# Out:
# dict_keys(['store', 'genre', 'area', 'weekday', 'holiday', 'year', 'month', 'day', 'dayofyear', 'quarter', 'dayof_quarter'])

# %%
result = pd.read_csv('sub1.csv')

# %%
result.head()
# Out:
#                                 id   visitors
# 0  air_00a91d42b08b08d9_2017-04-23  37.720238
# 1  air_0164b9927d20bcc3_2017-04-23   7.191416
# 2  air_0241aa3964b7f861_2017-04-23  10.825824
# 3  air_0328696196e46f18_2017-04-23  13.505601
# 4  air_034a3d5b40d5b1b1_2017-04-23  25.329669
