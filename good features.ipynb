# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from time import time
from hyperopt import hp
from hyperopt import fmin, tpe

# %%
date_2016 = pd.date_range(start = '2016-01-01',end='2016-12-31',freq='D')
date_2017 = pd.date_range(start = '2017-01-01',end='2017-12-31',freq='D')

# %%
date_2016_df = pd.DataFrame({'quarter':date_2016.quarter,'ones':np.ones(len(date_2016)),'date':pd.Series(date_2016.date).apply(str)})
date_2017_df = pd.DataFrame({'quarter':date_2017.quarter,'ones':np.ones(len(date_2017)),'date':pd.Series(date_2017.date).apply(str)})

# %%
date_2017_df.head()
# Out:
#          date  ones  quarter
# 0  2017-01-01   1.0        1
# 1  2017-01-02   1.0        1
# 2  2017-01-03   1.0        1
# 3  2017-01-04   1.0        1
# 4  2017-01-05   1.0        1

# %%
date_2016_df['dayofquarter']=date_2016_df.groupby('quarter',as_index=False)['ones'].cumsum()
date_2017_df['dayofquarter']=date_2017_df.groupby('quarter',as_index=False)['ones'].cumsum()

# %%
quarter_info = pd.concat([date_2016_df[['date','dayofquarter']],date_2017_df[['date','dayofquarter']]],axis=0)

# %%
quarter_info.head()
# Out:
#          date  dayofquarter
# 0  2016-01-01           1.0
# 1  2016-01-02           2.0
# 2  2016-01-03           3.0
# 3  2016-01-04           4.0
# 4  2016-01-05           5.0

# %%
quarter_info['quarter'] = pd.to_datetime(quarter_info.date).dt.quarter

# %%
quarter_info['day'] = pd.to_datetime(quarter_info.date).dt.day
quarter_info['dayofyear'] = pd.to_datetime(quarter_info.date).dt.dayofyear

# %%
quarter_info.head()
# Out:
#          date  dayofquarter  quarter  day  dayofyear
# 0  2016-01-01           1.0        1    1          1
# 1  2016-01-02           2.0        1    2          2
# 2  2016-01-03           3.0        1    3          3
# 3  2016-01-04           4.0        1    4          4
# 4  2016-01-05           5.0        1    5          5

# %%
quarter_info.shape
# Out:
# (731, 5)

# %% [markdown]
# ## ideas from kernel

# %%
kernel_train = pd.read_csv('kernel_train.csv')
kernel_test = pd.read_csv('kernel_test.csv')

# %%
kernel_train.head()
# Out:
#            air_store_id  visit_date  visitors  dow  year  month  day_of_week  \
# 0  air_ba937bf13d40fb24  2016-01-13        25    2  2016      1            6
# 1  air_ba937bf13d40fb24  2016-01-20        31    2  2016      1            6
# 2  air_ba937bf13d40fb24  2016-01-27        24    2  2016      1            6
# 3  air_ba937bf13d40fb24  2016-02-03        18    2  2016      2            6
# 4  air_ba937bf13d40fb24  2016-02-10        32    2  2016      2            6
#
#    holiday_flg  min_visitors  mean_visitors      ...        rv2_y  \
# 0            0           7.0       23.84375      ...         -1.0
# 1            0           7.0       23.84375      ...         -1.0
# 2            0           7.0       23.84375      ...         -1.0
# 3            0           7.0       23.84375      ...         -1.0
# 4            0           7.0       23.84375      ...         -1.0
#
#                                 id  total_reserv_sum  total_reserv_mean  \
# 0  air_ba937bf13d40fb24_2016-01-13              -1.0               -1.0
# 1  air_ba937bf13d40fb24_2016-01-20              -1.0               -1.0
# 2  air_ba937bf13d40fb24_2016-01-27              -1.0               -1.0
# 3  air_ba937bf13d40fb24_2016-02-03              -1.0               -1.0
# 4  air_ba937bf13d40fb24_2016-02-10              -1.0               -1.0
#
#    total_reserv_dt_diff_mean  date_int  var_max_lat  var_max_long  \
# 0                       -1.0  20160113     8.362564      4.521799
# 1                       -1.0  20160120     8.362564      4.521799
# 2                       -1.0  20160127     8.362564      4.521799
# 3                       -1.0  20160203     8.362564      4.521799
# 4                       -1.0  20160210     8.362564      4.521799
#
#    lon_plus_lat  air_store_id2
# 0    175.409667            599
# 1    175.409667            599
# 2    175.409667            599
# 3    175.409667            599
# 4    175.409667            599
#
# [5 rows x 54 columns]

# %%
len(train_data.visit_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-55c5e6d75747> in <module>()
# ----> 1 len(train_data.visit_date)
#
# NameError: name 'train_data' is not defined

# %%
len(kernel_train.visit_date)

# %%
test_data.shape,kernel_test.shape

# %%
kernel_train.columns
# Out:
# Index(['air_store_id', 'visit_date', 'visitors', 'dow', 'year', 'month',
#        'day_of_week', 'holiday_flg', 'min_visitors', 'mean_visitors',
#        'median_visitors', 'max_visitors', 'count_observations',
#        'air_genre_name', 'air_area_name', 'latitude', 'longitude',
#        'air_genre_name0', 'air_area_name0', 'air_genre_name1',
#        'air_area_name1', 'air_genre_name2', 'air_area_name2',
#        'air_genre_name3', 'air_area_name3', 'air_genre_name4',
#        'air_area_name4', 'air_genre_name5', 'air_area_name5',
#        'air_genre_name6', 'air_area_name6', 'air_genre_name7',
#        'air_area_name7', 'air_genre_name8', 'air_area_name8',
#        'air_genre_name9', 'air_area_name9', 'rs1_x', 'rv1_x', 'rs2_x', 'rv2_x',
#        'rs1_y', 'rv1_y', 'rs2_y', 'rv2_y', 'id', 'total_reserv_sum',
#        'total_reserv_mean', 'total_reserv_dt_diff_mean', 'date_int',
#        'var_max_lat', 'var_max_long', 'lon_plus_lat', 'air_store_id2'],
#       dtype='object')

# %%
train_data = pd.merge(left=kernel_train,right=quarter_info,how='left',
                     left_on='visit_date',right_on='date')

# %%
test_data = pd.merge(left=kernel_test,right=quarter_info,how='left',
                    left_on='visit_date',right_on='date')

# %%
test_data.head()
# Out:
#                                 id  visitors  visit_date  \
# 0  air_00a91d42b08b08d9_2017-04-23         0  2017-04-23
# 1  air_00a91d42b08b08d9_2017-04-24         0  2017-04-24
# 2  air_00a91d42b08b08d9_2017-04-25         0  2017-04-25
# 3  air_00a91d42b08b08d9_2017-04-26         0  2017-04-26
# 4  air_00a91d42b08b08d9_2017-04-27         0  2017-04-27
#
#            air_store_id  dow  year  month  day_of_week  holiday_flg  \
# 0  air_00a91d42b08b08d9    6  2017      4            3            0
# 1  air_00a91d42b08b08d9    0  2017      4            1            0
# 2  air_00a91d42b08b08d9    1  2017      4            5            0
# 3  air_00a91d42b08b08d9    2  2017      4            6            0
# 4  air_00a91d42b08b08d9    3  2017      4            4            0
#
#    min_visitors    ...      date_int  var_max_lat  var_max_long  lon_plus_lat  \
# 0           2.0    ...      20170423     8.326629      4.519803    175.447598
# 1           1.0    ...      20170424     8.326629      4.519803    175.447598
# 2           1.0    ...      20170425     8.326629      4.519803    175.447598
# 3          15.0    ...      20170426     8.326629      4.519803    175.447598
# 4          15.0    ...      20170427     8.326629      4.519803    175.447598
#
#    air_store_id2        date  dayofquarter  quarter  day  dayofyear
# 0              0  2017-04-23          23.0        2   23        113
# 1              0  2017-04-24          24.0        2   24        114
# 2              0  2017-04-25          25.0        2   25        115
# 3              0  2017-04-26          26.0        2   26        116
# 4              0  2017-04-27          27.0        2   27        117
#
# [5 rows x 59 columns]

# %%
train_data.shape,test_data.shape
# Out:
# ((250468, 59), (32019, 59))

# %%
len(set(test_data.visit_date)),len(set(train_data.visit_date))
# Out:
# (39, 478)

# %%
train_date = pd.DataFrame(list(set(train_data.visit_date))).rename(columns={0:'visit_date'})

# %%
train_date.sort_values('visit_date',inplace=True)

# %%
train_date['range'] = np.arange(train_date.shape[0])

# %%
train_date['train'] = train_date.range.apply(lambda x:x<448)
train_date['test'] = train_date.range.apply(lambda x:x>=448)

# %%
train_test = pd.merge(left=train_data,right=train_date[['visit_date','train','test']],
                     how='left',left_on='visit_date',right_on='visit_date')

# %%
train_set = train_test[train_test.train]
val_set = train_test[train_test.test]

# %%
train_data.shape,train_test.shape,train_set.shape,val_set.shape
# Out:
# ((250468, 59), (250468, 61), (228882, 61), (21586, 61))

# %%
train_set.columns
# Out:
# Index(['air_store_id', 'visit_date', 'visitors', 'dow', 'year', 'month',
#        'day_of_week', 'holiday_flg', 'min_visitors', 'mean_visitors',
#        'median_visitors', 'max_visitors', 'count_observations',
#        'air_genre_name', 'air_area_name', 'latitude', 'longitude',
#        'air_genre_name0', 'air_area_name0', 'air_genre_name1',
#        'air_area_name1', 'air_genre_name2', 'air_area_name2',
#        'air_genre_name3', 'air_area_name3', 'air_genre_name4',
#        'air_area_name4', 'air_genre_name5', 'air_area_name5',
#        'air_genre_name6', 'air_area_name6', 'air_genre_name7',
#        'air_area_name7', 'air_genre_name8', 'air_area_name8',
#        'air_genre_name9', 'air_area_name9', 'rs1_x', 'rv1_x', 'rs2_x', 'rv2_x',
#        'rs1_y', 'rv1_y', 'rs2_y', 'rv2_y', 'id', 'total_reserv_sum',
#        'total_reserv_mean', 'total_reserv_dt_diff_mean', 'date_int',
#        'var_max_lat', 'var_max_long', 'lon_plus_lat', 'air_store_id2', 'date',
#        'dayofquarter', 'quarter', 'day', 'dayofyear', 'train', 'test'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['id', 'visitors', 'visit_date', 'air_store_id', 'dow', 'year', 'month',
#        'day_of_week', 'holiday_flg', 'min_visitors', 'mean_visitors',
#        'median_visitors', 'max_visitors', 'count_observations',
#        'air_genre_name', 'air_area_name', 'latitude', 'longitude',
#        'air_genre_name0', 'air_area_name0', 'air_genre_name1',
#        'air_area_name1', 'air_genre_name2', 'air_area_name2',
#        'air_genre_name3', 'air_area_name3', 'air_genre_name4',
#        'air_area_name4', 'air_genre_name5', 'air_area_name5',
#        'air_genre_name6', 'air_area_name6', 'air_genre_name7',
#        'air_area_name7', 'air_genre_name8', 'air_area_name8',
#        'air_genre_name9', 'air_area_name9', 'rs1_x', 'rv1_x', 'rs2_x', 'rv2_x',
#        'rs1_y', 'rv1_y', 'rs2_y', 'rv2_y', 'total_reserv_sum',
#        'total_reserv_mean', 'total_reserv_dt_diff_mean', 'date_int',
#        'var_max_lat', 'var_max_long', 'lon_plus_lat', 'air_store_id2', 'date',
#        'dayofquarter', 'quarter', 'day', 'dayofyear'],
#       dtype='object')

# %%
train_x = train_set.drop(['air_store_id','visit_date','visitors','train','test','date','id','air_genre_name3',
                         'air_genre_name4','air_genre_name5','air_genre_name6','air_genre_name7','air_genre_name8',
                         'air_genre_name9','air_area_name7','air_area_name8','air_area_name9','day_of_week',
                         'air_genre_name', 'air_area_name', 'latitude', 'longitude'],axis=1)
train_y = np.log1p(train_set.visitors.values)
val_x = val_set.drop(['air_store_id','visit_date','visitors','train','test','date','id','air_genre_name3',
                         'air_genre_name4','air_genre_name5','air_genre_name6','air_genre_name7','air_genre_name8',
                         'air_genre_name9','air_area_name7','air_area_name8','air_area_name9','day_of_week',
                     'air_genre_name', 'air_area_name', 'latitude', 'longitude',],axis=1)
val_y = np.log1p(val_set.visitors.values)
test_set = test_data.drop(['air_store_id','visit_date','visitors','date','id','air_genre_name3',
                         'air_genre_name4','air_genre_name5','air_genre_name6','air_genre_name7','air_genre_name8',
                         'air_genre_name9','air_area_name7','air_area_name8','air_area_name9','day_of_week',
                          'air_genre_name', 'air_area_name', 'latitude', 'longitude',],axis=1)

# %%
holiday_flg, min_visitors, mean_visitors, median_visitors, max_visitors, count_observations,
        rs1_x, rv1_x, rs2_x, rv2_x, rs1_y, rv1_y, rs2_y, rv2_y, total_reserv_sum, total_reserv_mean,
        total_reserv_dt_diff_mean, date_int, var_max_lat, var_max_long, lon_plus_lat,
        dow, year, month, air_store_id, air_area_code, air_genre_code

# %%
train_x.columns
# Out:
# Index(['dow', 'year', 'month', 'holiday_flg', 'min_visitors', 'mean_visitors',
#        'median_visitors', 'max_visitors', 'count_observations',
#        'air_genre_name0', 'air_area_name0', 'air_genre_name1',
#        'air_area_name1', 'air_genre_name2', 'air_area_name2', 'air_area_name3',
#        'air_area_name4', 'air_area_name5', 'air_area_name6', 'rs1_x', 'rv1_x',
#        'rs2_x', 'rv2_x', 'rs1_y', 'rv1_y', 'rs2_y', 'rv2_y',
#        'total_reserv_sum', 'total_reserv_mean', 'total_reserv_dt_diff_mean',
#        'date_int', 'var_max_lat', 'var_max_long', 'lon_plus_lat',
#        'air_store_id2', 'dayofquarter', 'quarter', 'day', 'dayofyear'],
#       dtype='object')

# %% [markdown]
# train_data.to_csv('full_train_set.csv',index=False)
# train_set.to_csv('train_set.csv',index=False)
# val_set.to_csv('val_set.csv',index=False)
# test_data.to_csv('test_set.csv',index=False)

# %%
train_x.head()
# Out:
#    dow  year  month  holiday_flg  min_visitors  mean_visitors  \
# 0    2  2016      1            0           7.0       23.84375
# 1    2  2016      1            0           7.0       23.84375
# 2    2  2016      1            0           7.0       23.84375
# 3    2  2016      2            0           7.0       23.84375
# 4    2  2016      2            0           7.0       23.84375
#
#    median_visitors  max_visitors  count_observations  air_genre_name0  \
# 0             25.0          57.0                64.0                4
# 1             25.0          57.0                64.0                4
# 2             25.0          57.0                64.0                4
# 3             25.0          57.0                64.0                4
# 4             25.0          57.0                64.0                4
#
#      ...      total_reserv_dt_diff_mean  date_int  var_max_lat  var_max_long  \
# 0    ...                           -1.0  20160113     8.362564      4.521799
# 1    ...                           -1.0  20160120     8.362564      4.521799
# 2    ...                           -1.0  20160127     8.362564      4.521799
# 3    ...                           -1.0  20160203     8.362564      4.521799
# 4    ...                           -1.0  20160210     8.362564      4.521799
#
#    lon_plus_lat  air_store_id2  dayofquarter  quarter  day  dayofyear
# 0    175.409667            599          13.0        1   13         13
# 1    175.409667            599          20.0        1   20         20
# 2    175.409667            599          27.0        1   27         27
# 3    175.409667            599          34.0        1    3         34
# 4    175.409667            599          41.0        1   10         41
#
# [5 rows x 39 columns]

# %% [markdown]
# ## build xgboost model

# %%
def retrive_y(data):
    return np.exp(data)-1

# %%
dtrain = xgb.DMatrix(train_x,train_y)
dvalid = xgb.DMatrix(val_x,val_y)

# %%
param = {
        'eta':0.35,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':3,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
}

# %%
start = time()
bst = xgb.train(param,dtrain,30)
preds = bst.predict(dvalid)
print(mean_squared_error(val_y,preds))
time()-start
# Out:
# 0.289008006136
# 13.048494815826416

# %%
param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':3,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
}
start = time()
hist = xgb.cv(param,dtrain,30,metrics='rmse')
print(hist['test-rmse-mean'].iloc[-1])
time()-start
# Out:
# 0.500548666667
# 27.412065267562866

# %%
for i in np.arange(0.01,0.2,0.01):
    param = {
        'eta':i,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':3,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 0.01 1.835412
# 0.02 1.39757633333
# 0.03 1.08464233333
# 0.04 0.867315666667
# 0.05 0.722148333333
# 0.06 0.629477333333
# 0.07 0.572941
# 0.08 0.539917666667
# 0.09 0.521863666667
# 0.1 0.511361666667
# 0.11 0.505778666667
# 0.12 0.502884
# 0.13 0.501483
# 0.14 0.500795333333
# 0.15 0.500548666667
# 0.16 0.501091666667
# 0.17 0.501071
# 0.18 0.501957
# 0.19 0.502389666667

# %%
for i in np.arange(0.2,0.36,0.01):
    param = {
        'eta':i,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':3,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 0.2 0.502664
# 0.21 0.504044333333
# 0.22 0.504632333333
# 0.23 0.505299333333
# 0.24 0.506541333333
# 0.25 0.507012333333
# 0.26 0.507979666667
# 0.27 0.508825333333
# 0.28 0.510170666667
# 0.29 0.511608
# 0.3 0.512655333333
# 0.31 0.514708333333
# 0.32 0.515088333333
# 0.33 0.517419
# 0.34 0.518488
# 0.35 0.520437333333

# %%
for i in np.arange(1,20,1):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':i,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 1 0.501207
# 2 0.501058666667
# 3 0.500548666667
# 4 0.500074333333
# 5 0.500173666667
# 6 0.499984666667
# 7 0.500018
# 8 0.499570666667
# 9 0.499462
# 10 0.498860666667
# 11 0.499178666667
# 12 0.498834
# 13 0.498709
# 14 0.498713
# 15 0.498436666667
# 16 0.49877
# 17 0.498582666667
# 18 0.498371333333
# 19 0.498542

# %%
for i in np.arange(20,30,1):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':i,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 20 0.498064333333
# 21 0.498297333333
# 22 0.497943666667
# 23 0.498256333333
# 24 0.498246333333
# 25 0.498523
# 26 0.498208333333
# 27 0.497913333333
# 28 0.497941333333
# 29 0.497657333333

# %%
for i in np.arange(30,40,1):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':i,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 30 0.498411333333
# 31 0.497942666667
# 32 0.498162333333
# 33 0.497960333333
# 34 0.497981333333
# 35 0.497881666667
# 36 0.497764
# 37 0.498094
# 38 0.497864333333
# 39 0.498269666667

# %%
for i in np.arange(80,200,10):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':29,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':i
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 80 0.498008666667
# 90 0.498147666667
# 100 0.498273
# 110 0.497862333333
# 120 0.49797
# 130 0.497962666667
# 140 0.498017666667
# 150 0.497657333333
# 160 0.498506333333
# 170 0.498372333333
# 180 0.497745
# 190 0.497954

# %%
for i in np.arange(145,155,1):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.9,'colsample_bytree':0.9,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':29,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':i
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
# Out:
# 145 0.498095333333
# 146 0.498026666667
# 147 0.497887666667
# 148 0.497805666667
# 149 0.498251333333
# 150 0.497657333333
# 151 0.498152666667
# 152 0.498289
# 153 0.497934
# 154 0.498155

# %%
for i in np.arange(0.7,1,0.01):
    for j in np.arange(0.7,1,0.01):
        param = {
            'eta':0.15,'max_depth':16,'subsample':i,'colsample_bytree':j,'lamdba':0.3,'alpha':0.8,\
            'min_child_weight':29,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
            'tree_method':'hist','max_bin':150
        }
        hist = xgb.cv(param,dtrain,30,metrics='rmse')
        print(i,j,hist['test-rmse-mean'].iloc[-1])
# Out:
# 0.7 0.7 0.498728666667
# 0.7 0.71 0.498728666667
# 0.7 0.72 0.498836333333
# 0.7 0.73 0.498836333333
# 0.7 0.74 0.498836333333
# 0.7 0.75 0.498727333333
# 0.7 0.76 0.498727333333
# 0.7 0.77 0.498846666667
# 0.7 0.78 0.498846666667
# 0.7 0.79 0.498846666667
# 0.7 0.8 0.499339333333
# 0.7 0.81 0.499339333333
# 0.7 0.82 0.499339333333
# 0.7 0.83 0.499025333333
# 0.7 0.84 0.499025333333
# 0.7 0.85 0.499224
# 0.7 0.86 0.499224
# 0.7 0.87 0.499224
# 0.7 0.88 0.499051333333
# 0.7 0.89 0.499051333333
# 0.7 0.9 0.499205666667
# 0.7 0.91 0.499205666667
# 0.98 0.81 0.497879666667
# 0.98 0.82 0.497879666667
# 0.98 0.83 0.498009666667
# 0.98 0.84 0.498009666667
# 0.98 0.85 0.498045
# 0.98 0.86 0.498045
# 0.98 0.87 0.498045
# 0.98 0.88 0.498121666667
# 0.98 0.89 0.498121666667
# 0.98 0.9 0.49793
# 0.98 0.91 0.49793
# 0.98 0.92 0.49793
# 0.98 0.93 0.498023666667
# 0.98 0.94 0.498023666667
# 0.98 0.95 0.498373
# 0.98 0.96 0.498373
# 0.98 0.97 0.498373
# 0.98 0.98 0.498235666667
# 0.98 0.99 0.498235666667
# 0.98 1.0 0.498176333333
# 0.99 0.7 0.497577
# 0.99 0.71 0.497577
# 0.99 0.72 0.497701333333
# 0.99 0.73 0.497701333333
# 0.99 0.74 0.497701333333
# 0.99 0.75 0.497569666667
# 0.99 0.76 0.497569666667
# 0.99 0.77 0.497854333333
# 0.99 0.78 0.497854333333
# 0.99 0.79 0.497854333333
# 0.99 0.8 0.497866333333
# 0.99 0.81 0.497866333333
# 0.99 0.82 0.497866333333
# 0.99 0.83 0.497762
# 0.99 0.84 0.497762
# 0.99 0.85 0.497944666667
# 0.99 0.86 0.497944666667
# 0.99 0.87 0.497944666667
# 0.99 0.88 0.497702666667
# 0.99 0.89 0.497702666667
# 0.99 0.9 0.498327666667
# 0.99 0.91 0.498327666667
# 0.99 0.92 0.498327666667
# 0.99 0.93 0.498168666667
# 0.99 0.94 0.498168666667
# 0.99 0.95 0.498170333333
# 0.99 0.96 0.498170333333
# 0.99 0.97 0.498170333333
# 0.99 0.98 0.498300666667
# 0.99 0.99 0.498300666667
# 0.99 1.0 0.498306
# 1.0 0.7 0.497782
# 1.0 0.71 0.497782
# 1.0 0.72 0.497736333333
# 1.0 0.73 0.497736333333
# 1.0 0.74 0.497736333333
# 1.0 0.75 0.497782666667
# 1.0 0.76 0.497782666667
# 1.0 0.77 0.497645333333
# 1.0 0.78 0.497645333333
# 1.0 0.79 0.497645333333
# 1.0 0.8 0.497876666667
# 1.0 0.81 0.497876666667
# 1.0 0.82 0.497876666667
# 1.0 0.83 0.497848666667
# 1.0 0.84 0.497848666667
# 1.0 0.85 0.497949666667
# 1.0 0.86 0.497949666667
# 1.0 0.87 0.497949666667
# 1.0 0.88 0.498079666667
# 1.0 0.89 0.498079666667
# 1.0 0.9 0.497925
# 1.0 0.91 0.497925
# 1.0 0.92 0.497925
# 1.0 0.93 0.497976333333
# 1.0 0.94 0.497976333333
# 1.0 0.95 0.498405
# 1.0 0.96 0.498405
# 1.0 0.97 0.498405
# 1.0 0.98 0.498355
# 1.0 0.99 0.498355
# 1.0 1.0 0.498387666667

# %%
for i in np.arange(145,155,1):
    param = {
        'eta':0.15,'max_depth':16,'subsample':0.94,'colsample_bytree':0.73,'lamdba':0.3,'alpha':0.8,\
        'min_child_weight':29,'num_boost_round':100,'objective':'reg:linear','booster':'gbtree',\
        'tree_method':'hist','max_bin':150
    }
    hist = xgb.cv(param,dtrain,30,metrics='rmse')
    print(i,hist['test-rmse-mean'].iloc[-1])
